# %%
# Light-GG
# Memory saving algorithm to create a coordinate system (2D), but with human-intuitive inputs
# Application : sky coordinates, R.A. and Dec., orthogonal approximation

# %%
#import the necessary packages
import numpy as np

# %% [markdown]
# Create a sky coordinate grid.
# This is a uniform grid of RA and Dec, orthogonal approximation (right angle squares).
# It can be applied to a small region of the sky.

# %%
# creating the axes with evenly spaced coordinate spots
# this technique saves memory in Python, and is commonly used
vector_sky_ra = np.linspace (start_alpha, end_alpha, N_points_alpha)
vector_sky_dec = np.linspace (start_delta, end_delta, N_points_delta)

# This line of code creates 1D vectors for each axis: RA and Dec coordinate axes.
# np.linspace creates basically a 1D array (a vector) of evenly spaced numbers within a set interval.

# %% [markdown]
# # Grid description
#
# RA axis has 3600 points.
# Dec axis also has 3600 points.
# The total number of tiles is 3600x3600 = 12 960 000 tiles
